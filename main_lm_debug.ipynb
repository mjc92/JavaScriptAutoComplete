# %%
# about running mode
parser.add_argument("--mode",type=str, help='whether "train" or "test" data')
parser.add_argument("--model",type=str, help='which model to use')
parser.add_argument("--dataset_name",type=str, help='name of preprocessed dataset')
parser.add_argument("--dataset_dir",type=str, default= '/home/irteam/users/data/150kJavaScript/', 
                    help='name of preprocessed dataset')
parser.add_argument("--save_dir",type=str, default= 'None', 
                    help='where to save models / where saved models are')
parser.add_argument("--startfrom",type=int, default=0, help='whether starting from a previous model')


# model information
parser.add_argument("--embed_size",type=int, default=128, help='embedding size')
parser.add_argument("--hidden_size",type=int, default=1024, help='hidden size')
parser.add_argument("--num_layers",type=int, default=1, help='number of LSTM layers')
parser.add_argument("--num_epochs",type=int, default=10, help='number of epochs to run')
parser.add_argument("--batch_size",type=int, default=100, help='size of minibatch')
parser.add_argument("--seq_length",type=int, default=50, help='length of sequence size')
parser.add_argument("--out_seq",type=int, default=50, help='length of output sequence for encoder-decoder')
parser.add_argument("--lr",type=float, default=0.002, help='learning rate size')
parser.add_argument("--vocab_size",type=int, default=50000, help='vocab_size')
parser.add_argument("--max_oovs",type=int, default=30, help='max number of oovs per sample')
parser.add_argument("--seq2seq",type=str, help='which type of seq2seq to apply\
                    :\n[m2m] - many to many (in: 0~n / out: 1~n+1)\
                     \n[m2o] - many to one (in: 0~n / out: n+1)\
                     \n[ed]  - encoder-decoder (in: 0~n / out: n+1~??')

args = parser.parse_args()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f651ed038493> in <module>()
#       1 # about running mode
# ----> 2 parser.add_argument("--mode",type=str, help='whether "train" or "test" data')
#       3 parser.add_argument("--model",type=str, help='which model to use')
#       4 parser.add_argument("--dataset_name",type=str, help='name of preprocessed dataset')
#       5 parser.add_argument("--dataset_dir",type=str, default= '/home/irteam/users/data/150kJavaScript/',
#
# NameError: name 'parser' is not defined

# %%
import os
import torch 
import torch.nn as nn
import numpy as np
import argparse
import pickle
from torch.autograd import Variable
from packages.vocab import Vocab
from packages.batch import Batch
from slimit.lexer import Lexer
from packages.functions import detach, to_cuda, num_to_var, pack_padding, decoder_initial

# %%
class Args(object):
    mode = 'train'
    model = 'copynet'
    dataset_name = 'data_lexed'
    dataset_dir = '/home/irteam/users/data/150kJavaScript/'
    save_dir = 'None'
    startfrom = 0
    
    embed_size = 150
    hidden_size = 300
    num_layers = 1
    num_epochs = 10
    batch_size = 3
    seq_length = 50
    out_seq = 10
    lr = 0.002
    vocab_size = 50000
    max_oovs = 30
    seq2seq = 'stmt'
args = Args()

# %%
if args.model=='lm':
    from models.lstm.model import RNNLM
    from models.lstm.solver import train,test
elif args.model=='copynet':
    from models.copynet.model import CopyEncoder, CopyDecoder
    from models.copynet.solver import train

with open(os.path.join(args.dataset_dir,args.mode,('file_list_%s.txt'%args.dataset_name))) as f:
    file_list = f.read().split('\n')

batch = Batch(file_dir=os.path.join(args.dataset_dir,args.mode,args.dataset_name),
              file_list=file_list,
              batch_size=args.batch_size,
              in_seq=args.seq_length,
              out_seq=args.out_seq,
              max_oovs=args.max_oovs,
              seq2seq=args.seq2seq)

idx2id = np.load('vocab/data_lexed/idx2id.npy').item()
idx2tok = np.load('vocab/data_lexed/idx2tok.npy').item()
idx2reg = np.load('vocab/data_lexed/idx2reg.npy').item()
word_list = [x for (_,x) in idx2tok.items()] + [x for (_,x) in idx2reg.items()][:1000] + \
        [x for (_,x) in idx2id.items()][:args.vocab_size]
vocab = Vocab(args.vocab_size)
vocab.add_to_vocab(word_list)
print("Vocab size: %d" %vocab.count)

# import lexer
lexer = Lexer()

# set directory to save model
if args.save_dir=='None':
    save_dir = os.path.join('saved_weights',args.model)
else:
    save_dir = args.save_dir

print("Saving models in %s..." %save_dir)
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
# Out:
# Vocabulary max size reached!
# Vocab size: 50000
# Saving models in saved_weights/copynet...

# %%
if args.startfrom==0:
    print("Loading new %s model..." %args.model)
    if args.model == 'lm':
        model = RNNLM(vocab.max_size, embed_size=args.embed_size, hidden_size=args.hidden_size,
                         num_layers = args.num_layers)
        model.cuda()
    elif args.model == 'copynet':
        encoder = CopyEncoder(args.vocab_size, args.embed_size, args.hidden_size)
        decoder = CopyDecoder(args.vocab_size, args.embed_size, args.hidden_size, args.max_oovs)
        encoder.cuda()
        decoder.cuda()
        model = (encoder, decoder)
else:
    print("Loading %s model from %d epochs..." %(args.model, args.startfrom))
    if args.model == 'lm':
        model = torch.load(os.path.join(save_dir,'saved_model_%d_epochs.pckl'%args.startfrom))
        model.cuda()
    elif args.model == 'copynet':
        encoder.cuda()
        decoder.cuda()
        model = (encoder, decoder)
# # set loss function and optimizer
# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)
# Out:
# Loading new copynet model...

# %%
def train(args, batch, vocab, model, save_dir):
    
    # split model into encoder and decoder
    encoder,decoder = model
    
    # set loss function and optimizer
    criterion = nn.NLLLoss()
    opt_e = torch.optim.Adam(encoder.parameters(), lr=args.lr)
    opt_d = torch.optim.Adam(decoder.parameters(), lr=args.lr)
    
    step = 99999
    total_files = len(batch.full_list)
    print("Total number of files to read: %d" %total_files)

    for epoch in range(args.startfrom,args.num_epochs):
        print("===================== Epoch %d =====================" %(epoch+args.startfrom))

        batch.next_epoch(args.batch_size) # initialize batch data
        batch.initialize_states(args.num_layers, args.hidden_size)
        total_steps = step
        step=0
        while(batch.epoch_end==0):
            step+=1
            # update the minibatch inputs / outputs
            encoder.zero_grad()
            decoder.zero_grad()
            # get next minibatch
            batch.get_minibatch(0)
            
            # get inputs and targets from batch object
            for i in range(len(batch.batch_in)):
                in_line = batch.batch_in[i]
                out_line = batch.batch_out[i]
                oov2idx, idx2oov = vocab.create_oov_list(in_line+out_line, batch.max_oovs)
                batch.oov2idx_list.append(oov2idx)
                batch.idx2oov_list.append(idx2oov)
              
            inputs_oov_np = np.array([vocab.word_list_to_idx_list(line,batch.oov2idx_list[i]) for
                                 i,line in enumerate(batch.batch_in)],dtype=int)
            targets_oov_np = np.array([vocab.word_list_to_idx_list(line,batch.oov2idx_list[i]) for
                                 line in batch.batch_out],dtype=int)
            inputs_unk_np = np.array([vocab.word_list_to_idx_list(line) for
                                 i,line in enumerate(batch.batch_in)],dtype=int)
            targets_unk_np = np.array([vocab.word_list_to_idx_list(line) for
                                 line in batch.batch_out],dtype=int)
            for i in range(batch.batch_size):
                print('IN ',i,": ",' '.join(batch.batch_in[i][-10:]))
                print('OUT ',i,": ",' '.join(batch.batch_out[i]))
            print('\n')
            
            # whether to use teacher forcing
            if np.random.random_sample(size=1)[0]<(epoch*1.0/args.num_epochs):
                teacher_force = True
            else:
                teacher_force = False
                
            inputs = Variable(torch.LongTensor(inputs_unk_np)).cuda()
            targets = Variable(torch.LongTensor(targets_unk_np)).cuda()

            # run model to get outputs
            encoded, _ = encoder(inputs)
            
            decoder_in, s, w = decoder_initial(inputs.size(0),vocab.w2i['<SOS>'])
#             decoder_in = targets[:,0]
            
            for j in range(targets.size(1)):
                if j==0:
                    outputs,s,w = decoder(input_idx=decoder_in, encoded=encoded,
                        encoded_idx=inputs_oov_np,prev_state=s,
                        weighted=w, order=j)
                else:
                    tmp_out,s,w = decoder(input_idx=decoder_in, encoded=encoded,
                        encoded_idx=inputs_oov_np, prev_state=s,
                        weighted=w, order=j)
                    outputs = torch.cat([outputs,tmp_out],dim=1)
                
                # if teacher_force:
                #     decoder_in = out[:,-1,:].max(1)[1].squeeze()
                # else:
                decoder_in = targets[:,j] # train with ground truth
            
            targets = Variable(torch.LongTensor(targets_oov_np)).cuda()
            targets, outputs = pack_padding(targets, outputs)
#             print("Target size: ",targets.size())
#             print(' '.join([str(x.data[0]) for x in targets[:100]]))
#             print("Output size: ",outputs.size())
#             print('==============================')
            loss = criterion(torch.log(outputs), targets.view(-1))
            loss.backward()
            torch.nn.utils.clip_grad_norm(encoder.parameters(),0.5)
            torch.nn.utils.clip_grad_norm(decoder.parameters(),0.5)
            opt_e.step()
            opt_d.step()

            batch.next_minibatch()
#             print("next minibatch done?")
#             for i in range(batch.batch_size):
#                 print("remaining file list: ", len(batch.batch_data[i]))
            if step%10==0:
                print ('Epoch [%d/%d], Files: [%d/%d],  Loss: %.3f, Steps: [%d/%d],\
                Perplexity: %5.2f' %
               (epoch+args.startfrom, args.num_epochs, total_files-len(batch.file_list),
                total_files, loss.data[0], step, total_steps, np.exp(loss.data[0])))
        # save model at end of each epoch
        torch.save(f=os.path.join(save_dir,'saved_encoder_%d_epochs.pckl')%(epoch+args.startfrom),obj=encoder)
        torch.save(f=os.path.join(save_dir,'saved_decoder_%d_epochs.pckl')%(epoch+args.startfrom),obj=decoder)

# %%
print(args)
if args.mode=='train':
    train(args,batch,vocab,model,save_dir)
# Out:
# <__main__.Args object at 0x7f603354a198>
# Total number of files to read: 99815
# ===================== Epoch 0 =====================
# IN  0 :  ( BUGNUMBER ) ; printStatus ( summary ) ; jit
# OUT  0 :  ( true ) ; <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# IN  1 :  Migrator . prototype . get = function ( name )
# OUT  1 :  { return this . store [ name ] ; <EOS>
# IN  2 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# OUT  2 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
#
#
# Time difference from state 0: 12.4040
# Time difference from state 1: 0.0057
# Time difference from state 2-1: 0.0018
# Time difference from state 2-2: 0.0017
# Time difference from state 2-3: 0.0032
# Time difference from state 2-4: 0.0017
# Time difference from state 2-5-1: 0.0026
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0043
# Time difference from state 2-5: 0.0175
# Time difference from state 3-1-1: 0.0042
# Time difference from state 3-1: 0.0083
# Time difference from state 3-2: 0.0015
# Time difference from state 0: 0.0008
# Time difference from state 1: 0.0045
# Time difference from state 2-1: 0.0087
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0024
# Time difference from state 2-4: 0.0021
# Time difference from state 2-5-1: 0.0033
# Time difference from state 2-5-2: 0.0005
# Time difference from state 2-5-3: 0.0044
# Time difference from state 2-5: 0.0194
# Time difference from state 3-1-1: 0.0100
# Time difference from state 3-1: 0.0089
# Time difference from state 3-2: 0.0020
# Time difference from state 0: 0.0019
# Time difference from state 1: 0.0069
# Time difference from state 2-1: 0.0082
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0025
# Time difference from state 2-4: 0.0007
# Time difference from state 2-5-1: 0.0006
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0044
# Time difference from state 2-5: 0.0121
# Time difference from state 3-1-1: 0.0100
# Time difference from state 3-1: 0.0087
# Time difference from state 3-2: 0.0014
# Time difference from state 0: 0.0019
# Time difference from state 1: 0.0065
# Time difference from state 2-1: 0.0074
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0034
# Time difference from state 2-4: 0.0007
# Time difference from state 2-5-1: 0.0006
# Time difference from state 2-5-2: 0.0005
# Time difference from state 2-5-3: 0.0045
# Time difference from state 2-5: 0.0196
# Time difference from state 3-1-1: 0.0101
# Time difference from state 3-1: 0.0082
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0016
# Time difference from state 1: 0.0039
# Time difference from state 2-1: 0.0034
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0005
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0044
# Time difference from state 2-5: 0.0081
# Time difference from state 3-1-1: 0.0074
# Time difference from state 3-1: 0.0054
# Time difference from state 3-2: 0.0012
# Time difference from state 0: 0.0018
# Time difference from state 1: 0.0056
# Time difference from state 2-1: 0.0041
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0017
# Time difference from state 2-4: 0.0003
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0043
# Time difference from state 2-5: 0.0081
# Time difference from state 3-1-1: 0.0075
# Time difference from state 3-1: 0.0052
# Time difference from state 3-2: 0.0010
# Time difference from state 0: 0.0018
# Time difference from state 1: 0.0075
# Time difference from state 2-1: 0.0025
# Time difference from state 2-2: 0.0024
# Time difference from state 2-3: 0.0005
# Time difference from state 2-4: 0.0003
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0043
# Time difference from state 2-5: 0.0080
# Time difference from state 3-1-1: 0.0071
# Time difference from state 3-1: 0.0048
# Time difference from state 3-2: 0.0007
# Time difference from state 0: 0.0016
# Time difference from state 1: 0.0067
# Time difference from state 2-1: 0.0025
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0017
# Time difference from state 2-4: 0.0003
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0071
# Time difference from state 2-5: 0.0047
# Time difference from state 3-1-1: 0.0071
# Time difference from state 3-1: 0.0049
# Time difference from state 3-2: 0.0007
# Time difference from state 0: 0.0029
# Time difference from state 1: 0.0026
# Time difference from state 2-1: 0.0026
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0017
# Time difference from state 2-4: 0.0003
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0042
# Time difference from state 2-5: 0.0076
# Time difference from state 3-1-1: 0.0106
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0007
# Time difference from state 0: 0.0029
# Time difference from state 1: 0.0025
# Time difference from state 2-1: 0.0026
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0017
# Time difference from state 2-4: 0.0003
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0042
# Time difference from state 2-5: 0.0076
# Time difference from state 3-1-1: 0.0069
# Time difference from state 3-1: 0.0046
# Time difference from state 3-2: 0.0008
# IN  0 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# OUT  0 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# IN  1 :  if ( fn . length > 1 ) { fn
# OUT  1 :  = Promise . promisify ( fn ) ; <EOS> <PAD>
# IN  2 :  IcalComponent ( ) { Abstract . apply ( this ,
# OUT  2 :  arguments ) ; <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
#
#
# Time difference from state 0: 0.2855
# Time difference from state 1: 0.0012
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0047
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0005
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0002
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0047
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0006
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0048
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0047
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0010
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0046
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0120
# Time difference from state 3-1: 0.0012
# Time difference from state 3-2: 0.0009
# Time difference from state 0: 0.0007
# Time difference from state 1: 0.0018
# Time difference from state 2-1: 0.0018
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0005
# Time difference from state 2-5-1: 0.0005
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0049
# Time difference from state 2-5: 0.0061
# Time difference from state 3-1-1: 0.0046
# Time difference from state 3-1: 0.0047
# Time difference from state 3-2: 0.0011
# Time difference from state 0: 0.0006
# Time difference from state 1: 0.0017
# Time difference from state 2-1: 0.0017
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0006
# Time difference from state 2-5-1: 0.0004
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0233
# Time difference from state 2-5: 0.0147
# Time difference from state 3-1-1: 0.0049
# Time difference from state 3-1: 0.0090
# Time difference from state 3-2: 0.0012
# Time difference from state 0: 0.0006
# Time difference from state 1: 0.0018
# Time difference from state 2-1: 0.0018
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0067
# Time difference from state 2-4: 0.0006
# Time difference from state 2-5-1: 0.0005
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0079
# Time difference from state 2-5: 0.0149
# Time difference from state 3-1-1: 0.0089
# Time difference from state 3-1: 0.0101
# Time difference from state 3-2: 0.0013
# Time difference from state 0: 0.0006
# Time difference from state 1: 0.0032
# Time difference from state 2-1: 0.0032
# Time difference from state 2-2: 0.0061
# Time difference from state 2-3: 0.0012
# Time difference from state 2-4: 0.0006
# Time difference from state 2-5-1: 0.0005
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0130
# Time difference from state 2-5: 0.0145
# Time difference from state 3-1-1: 0.0041
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0016
# Time difference from state 1: 0.0034
# Time difference from state 2-1: 0.0030
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0006
# Time difference from state 2-5-1: 0.0005
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0050
# Time difference from state 2-5: 0.0102
# Time difference from state 3-1-1: 0.0072
# Time difference from state 3-1: 0.0046
# Time difference from state 3-2: 0.0010
# IN  0 :  . proliferate ( { "GameStartrConstructor" : FullScreenMario } , FullScreenMario
# OUT  0 :  . prototype . settings . ui , true ) )
# IN  1 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# OUT  1 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# IN  2 :  function ( ) { } , _createModel : function (
# OUT  2 :  object ) { return object ; <EOS> <PAD> <PAD> <PAD>
#
#
# Time difference from state 0: 0.3488
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0039
# Time difference from state 2-5: 0.0210
# Time difference from state 3-1-1: 0.0051
# Time difference from state 3-1: 0.0105
# Time difference from state 3-2: 0.0027
# Time difference from state 0: 0.0011
# Time difference from state 1: 0.0024
# Time difference from state 2-1: 0.0044
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0006
# Time difference from state 2-5-1: 0.0004
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0040
# Time difference from state 2-5: 0.0034
# Time difference from state 3-1-1: 0.0045
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0041
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0040
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0004
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0005
# Time difference from state 2-4: 0.0003
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0040
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0007
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0003
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0039
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0003
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0039
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0039
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0039
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0006
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0039
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0027
# IN  0 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# OUT  0 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# IN  1 :  0 , 0 , 0 , 400 ] , stops
# OUT  1 :  : [ [ 0 , 'rgb(96, 96, 96)' ] , [ 1
# IN  2 :  onerror = function ( event ) { callback ( event
# OUT  2 :  . target . error . name ) ; <EOS> <PAD>
#
#
# Time difference from state 0: 0.2123
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0049
# Time difference from state 2-5: 0.0083
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0048
# Time difference from state 2-5: 0.0011
# Time difference from state 3-1-1: 0.0041
# Time difference from state 3-1: 0.0010
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0057
# Time difference from state 2-5: 0.0011
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.1822
# Time difference from state 2-5: 0.0082
# Time difference from state 3-1-1: 0.0052
# Time difference from state 3-1: 0.0091
# Time difference from state 3-2: 0.0020
# Time difference from state 0: 0.0009
# Time difference from state 1: 0.0019
# Time difference from state 2-1: 0.0030
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0025
# Time difference from state 2-4: 0.0008
# Time difference from state 2-5-1: 0.0006
# Time difference from state 2-5-2: 0.0005
# Time difference from state 2-5-3: 0.0049
# Time difference from state 2-5: 0.0142
# Time difference from state 3-1-1: 0.0041
# Time difference from state 3-1: 0.0020
# Time difference from state 3-2: 0.0009
# Time difference from state 0: 0.0006
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0016
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0017
# Time difference from state 2-4: 0.0003
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0048
# Time difference from state 2-5: 0.0061
# Time difference from state 3-1-1: 0.0047
# Time difference from state 3-1: 0.0050
# Time difference from state 3-2: 0.0012
# Time difference from state 0: 0.0006
# Time difference from state 1: 0.0017
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0046
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0041
# Time difference from state 3-1: 0.0006
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0045
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0041
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0046
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0041
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0046
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0041
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# IN  0 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# OUT  0 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# IN  1 :  style : { color : '#FFF' , font : '16px Lucida Grande, Lucida Sans Unicode, Verdana, Arial, Helvetica, sans-serif'
# OUT  1 :  } } , subtitle : { style : { color
# IN  2 :  ) ; var idx = store . index ( 'lastRecurrenceId'
# OUT  2 :  ) ; <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
#
#
# Time difference from state 0: 0.2889
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0042
# Time difference from state 2-5: 0.0099
# Time difference from state 3-1-1: 0.0043
# Time difference from state 3-1: 0.0006
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0016
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0042
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0041
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0042
# Time difference from state 2-5: 0.0009
# Time difference from state 3-1-1: 0.0041
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0012
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0053
# Time difference from state 2-5: 0.0348
# Time difference from state 3-1-1: 0.0056
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0053
# Time difference from state 2-5: 0.0072
# Time difference from state 3-1-1: 0.0057
# Time difference from state 3-1: 0.0007
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0052
# Time difference from state 2-5: 0.0050
# Time difference from state 3-1-1: 0.0056
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0053
# Time difference from state 2-5: 0.0064
# Time difference from state 3-1-1: 0.0055
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0053
# Time difference from state 2-5: 0.0031
# Time difference from state 3-1-1: 0.0066
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0052
# Time difference from state 2-5: 0.0066
# Time difference from state 3-1-1: 0.0055
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0052
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0056
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0004
# IN  0 :  ) define ( factory ) ; else if ( typeof
# OUT  0 :  exports === 'object' ) exports [ "math" ] = factory
# IN  1 :  color : '#999' , fontWeight : 'bold' } } ,
# OUT  1 :  title : { style : { color : '#AAA' ,
# IN  2 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# OUT  2 :  <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
#
#
# Time difference from state 0: 0.8682
# Time difference from state 1: 0.0012
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0057
# Time difference from state 2-5: 0.0091
# Time difference from state 3-1-1: 0.0046
# Time difference from state 3-1: 0.0045
# Time difference from state 3-2: 0.0007
# Time difference from state 0: 0.0005
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0015
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0005
# Time difference from state 2-5-1: 0.0004
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0052
# Time difference from state 2-5: 0.0071
# Time difference from state 3-1-1: 0.0046
# Time difference from state 3-1: 0.0047
# Time difference from state 3-2: 0.0010
# Time difference from state 0: 0.0005
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0015
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0017
# Time difference from state 2-4: 0.0006
# Time difference from state 2-5-1: 0.0004
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0051
# Time difference from state 2-5: 0.0105
# Time difference from state 3-1-1: 0.0046
# Time difference from state 3-1: 0.0048
# Time difference from state 3-2: 0.0011
# Time difference from state 0: 0.0005
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0015
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0005
# Time difference from state 2-5-1: 0.0004
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0060
# Time difference from state 2-5: 0.0076
# Time difference from state 3-1-1: 0.0045
# Time difference from state 3-1: 0.0046
# Time difference from state 3-2: 0.0010
# Time difference from state 0: 0.0005
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0015
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0005
# Time difference from state 2-5-1: 0.0004
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0052
# Time difference from state 2-5: 0.0109
# Time difference from state 3-1-1: 0.0046
# Time difference from state 3-1: 0.0049
# Time difference from state 3-2: 0.0012
# Time difference from state 0: 0.0006
# Time difference from state 1: 0.0017
# Time difference from state 2-1: 0.0017
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0006
# Time difference from state 2-5-1: 0.0005
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0053
# Time difference from state 2-5: 0.0094
# Time difference from state 3-1-1: 0.0045
# Time difference from state 3-1: 0.0048
# Time difference from state 3-2: 0.0021
# Time difference from state 0: 0.0006
# Time difference from state 1: 0.0017
# Time difference from state 2-1: 0.0017
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0005
# Time difference from state 2-5-1: 0.0004
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0052
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0050
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0050
# Time difference from state 2-5: 0.0010
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0008
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0013
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0049
# Time difference from state 2-5: 0.0210
# Time difference from state 3-1-1: 0.0040
# Time difference from state 3-1: 0.0006
# Time difference from state 3-2: 0.0003
# IN  0 :  installedModules = { } ; function __webpack_require__ ( moduleId )
# OUT  0 :  { if ( installedModules [ moduleId ] ) return installedModules
# IN  1 :  labels : { style : { color : '#999' ,
# OUT  1 :  fontWeight : 'bold' } } , title : { style
# IN  2 :  : config . LOG_INFO , autoWatch : false , browsers
# OUT  2 :  : [ 'Chrome' ] , singleRun : false } )
#
#
# Time difference from state 0: 0.3317
# Time difference from state 1: 0.0057
# Time difference from state 2-1: 0.0015
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0019
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0005
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0051
# Time difference from state 2-5: 0.0224
# Time difference from state 3-1-1: 0.0053
# Time difference from state 3-1: 0.0067
# Time difference from state 3-2: 0.0008
# Time difference from state 0: 0.0005
# Time difference from state 1: 0.0014
# Time difference from state 2-1: 0.0014
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0005
# Time difference from state 2-5-1: 0.0004
# Time difference from state 2-5-2: 0.0003
# Time difference from state 2-5-3: 0.0053
# Time difference from state 2-5: 0.0052
# Time difference from state 3-1-1: 0.0045
# Time difference from state 3-1: 0.0047
# Time difference from state 3-2: 0.0010
# Time difference from state 0: 0.0006
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0016
# Time difference from state 2-2: 0.0015
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0005
# Time difference from state 2-5-1: 0.0004
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0067
# Time difference from state 2-5: 0.0075
# Time difference from state 3-1-1: 0.0046
# Time difference from state 3-1: 0.0048
# Time difference from state 3-2: 0.0011
# Time difference from state 0: 0.0006
# Time difference from state 1: 0.0017
# Time difference from state 2-1: 0.0017
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0016
# Time difference from state 2-4: 0.0006
# Time difference from state 2-5-1: 0.0005
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0060
# Time difference from state 2-5: 0.0089
# Time difference from state 3-1-1: 0.0064
# Time difference from state 3-1: 0.0010
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0016
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0049
# Time difference from state 2-5: 0.0011
# Time difference from state 3-1-1: 0.0044
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0003
# Time difference from state 0: 0.0003
# Time difference from state 1: 0.0016
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0003
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0049
# Time difference from state 2-5: 0.0011
# Time difference from state 3-1-1: 0.0044
# Time difference from state 3-1: 0.0011
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0004
# Time difference from state 1: 0.0016
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0049
# Time difference from state 2-5: 0.0011
# Time difference from state 3-1-1: 0.0044
# Time difference from state 3-1: 0.0014
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0004
# Time difference from state 1: 0.0016
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0002
# Time difference from state 2-5-2: 0.0004
# Time difference from state 2-5-3: 0.0047
# Time difference from state 2-5: 0.0012
# Time difference from state 3-1-1: 0.0045
# Time difference from state 3-1: 0.0010
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0004
# Time difference from state 1: 0.0018
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0047
# Time difference from state 2-5: 0.0033
# Time difference from state 3-1-1: 0.0044
# Time difference from state 3-1: 0.0009
# Time difference from state 3-2: 0.0004
# Time difference from state 0: 0.0004
# Time difference from state 1: 0.0015
# Time difference from state 2-1: 0.0003
# Time difference from state 2-2: 0.0016
# Time difference from state 2-3: 0.0004
# Time difference from state 2-4: 0.0004
# Time difference from state 2-5-1: 0.0003
# Time difference from state 2-5-2: 0.0002
# Time difference from state 2-5-3: 0.0049
# Time difference from state 2-5: 0.0025
# Time difference from state 3-1-1: 0.0044
# Time difference from state 3-1: 0.0007
# Time difference from state 3-2: 0.0004
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5b4c91d497fb> in <module>()
#       1 print(args)
#       2 if args.mode=='train':
# ----> 3     train(args,batch,vocab,model,save_dir)
#
# <ipython-input-5-547193af13bd> in train(args, batch, vocab, model, save_dir)
#      87 #             print('==============================')
#      88             loss = criterion(torch.log(outputs), targets.view(-1))
# ---> 89             loss.backward()
#      90             torch.nn.utils.clip_grad_norm(encoder.parameters(),0.5)
#      91             torch.nn.utils.clip_grad_norm(decoder.parameters(),0.5)
#
# ~/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     150                 Defaults to False, unless ``gradient`` is a volatile Variable.
#     151         """
# --> 152         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     153
#     154     def register_hook(self, hook):
#
# ~/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/autograd/__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      96
#      97     Variable._execution_engine.run_backward(
# ---> 98         variables, grad_variables, retain_graph)
#      99
#     100
#
# KeyboardInterrupt:

# %%
model = torch.load('saved_weights/gru/saved_model_8_epochs.pckl')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-48770120636a> in <module>()
# ----> 1 model = torch.load('saved_weights/gru/saved_model_8_epochs.pckl')
#
# ~/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     227         f = open(f, 'rb')
#     228     try:
# --> 229         return _load(f, map_location, pickle_module)
#     230     finally:
#     231         if new_fd:
#
# ~/anaconda3/envs/pytorch/lib/python3.5/site-packages/torch/serialization.py in _load(f, map_location, pickle_module)
#     375     unpickler = pickle_module.Unpickler(f)
#     376     unpickler.persistent_load = persistent_load
# --> 377     result = unpickler.load()
#     378
#     379     deserialized_storage_keys = pickle_module.load(f)
#
# ImportError: No module named 'models.bigru'
